# %%
import torch
from einops import einsum, rearrange

from cs336_basics.model import RoPE

# %%
d_model = 64
T = 12
nh = 4
bs = 8
theta = 10000
msl = 256

# %%
t = torch.randn(bs, T, d_model)
t.shape
# Out:
# torch.Size([8, 12, 64])

# %%
rearrange(t, '... T (nh d_k) -> ... nh T d_k', nh=nh)
# Out:
# tensor([[[[ 4.7920e-01, -1.5201e+00,  9.3093e-02,  ..., -8.3868e-01,
#            -2.3175e-01, -9.9113e-01],
#           [ 9.1469e-01, -1.4132e+00, -2.1605e+00,  ..., -8.1426e-01,
#            -5.9552e-01, -1.9635e-01],
#           [ 5.0202e-01,  6.0644e-01, -2.7342e-01,  ..., -3.7548e-01,
#             2.3671e-01, -1.4474e+00],
#           ...,
#           [ 1.2849e+00,  1.3162e-01, -2.2035e+00,  ..., -8.1353e-01,
#            -3.9992e-01, -1.7441e+00],
#           [-2.7494e-01,  9.2472e-01, -3.2162e-01,  ...,  4.4397e-01,
#             1.8106e-02,  8.7152e-01],
#           [-1.9375e+00, -1.9362e-01, -1.4073e-01,  ..., -4.5551e-01,
#             1.5156e+00, -1.2811e+00]],
#
#          [[ 7.9302e-01, -1.0914e+00,  4.1638e-01,  ...,  4.1994e-01,
#             3.9235e-01, -6.1339e-01],
#           [-3.0824e-01,  1.7325e+00, -1.2655e+00,  ...,  6.5882e-01,
#            -1.1933e+00, -3.6651e-01],
#           [-3.9066e-02, -1.2014e+00, -1.8469e-01,  ..., -1.6435e-01,
# ...
